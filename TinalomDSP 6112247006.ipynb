# %%
#ประกาศ เพื่อเรียกใช้งาน
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %%
#Lap01

sin_wave = thinkdsp.SinSignal(freq=7006, amp=0.6, offset=0)
sin_wave.plot()
thinkplot.config(xlabel='Time (s)')

# %%
#Lap02
#ค่าTrianglesignal(f)
#duration = signal.period*n

signal = thinkdsp.SinSignal(4000)
duration = signal.period*2500
segment = signal.make_wave(duration, framerate = 10000)
segment.plot()
tnwave = signal.make_wave(duration, framerate = 10000)
tnwave.apodize()
tnwave.make_audio()
spectrum = tnwave.make_spectrum()
spectrum.plot()

# %%
signaltn = thinkdsp.SquareSignal(4000)
duration = signaltn.period*2500
segment = signaltn.make_wave(duration, framerate = 10000)
segment.plot()
thinkplot.config(ylim=[-1.05, 1.05], legend=False)
segment.plot()
tnwave = signaltn.make_wave(duration, framerate = 10000)
tnwave.apodize()
tnwave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
